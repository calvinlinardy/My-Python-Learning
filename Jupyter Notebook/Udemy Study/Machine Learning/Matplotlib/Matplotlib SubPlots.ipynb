# %% [markdown]
# # Matplotlib SubPlots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.linspace(0,10,11)
b = a**4

# %%
x = np.arange(0,10)
y = 2*x

# %%
# ini agak complicated but stick with me
# jadi subplots ini itu tuples terdiri dari figure,axes nya
asdf = plt.subplots(nrows=1,ncols=2)

# %%
asdf
# bisa kita liat kan isinya itu tuple
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
# jadi kita buat subplots bisa langsung pisahin aja
fig,axes = plt.subplots()
# subplots itu emang di maksudkan buat beberapa figure jadi 1
# jadi kalo ga ada rows ato cols mending buat figure aja

# %%
# dan kita bisa liat fig sama axesnya
fig

# %%
axes
# Out:
# <AxesSubplot:>

# %%
type(axes) # type axesnya itu axes
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# skrg kita tambahin rows sama cols
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
fig

# %%
type(axes) # type axes nya jadi np array
# Out:
# numpy.ndarray

# %%
# kita liat shapenya
axes.shape
# 1 dimensional soalnya emang cuma ada 2 axes, kanan sama kiri
# Out:
# (2,)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# skrg tambahin plot
fig,axes = plt.subplots(nrows=1,ncols=2)

# pake index axesnya, inget axesnya itu array
# [0] = kiri, [1] = kanan
axes[0].plot(x,y)
axes[1].plot(a,b);

# %%
# skrg kita tambahin rows nya jadi 2x2
fig,axes = plt.subplots(nrows=2,ncols=2)

axes[0].plot(x,y)
axes[1].plot(a,b);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10464/4059081964.py in <module>
#       2 fig,axes = plt.subplots(nrows=2,ncols=2)
#       3
# ----> 4 axes[0].plot(x,y)
#       5 axes[1].plot(a,b);
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# ini error yang banyak beginner temuin, karena skrg size subplotsnya 2,2, jadi array axesnya juga jadi 2 dimensional, jadi axes[0] sama axes[1] itu 1 dimensional jadi error.

# %%
axes.shape
# Out:
# (2, 2)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Jadi harusnya gini

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)

axes[0][0].plot(x,y)
axes[0][1].plot(a,b);

# %%
# skrg kita coba ubah jadi 3x1
fig,axes = plt.subplots(nrows=3,ncols=1)

# %% [markdown]
# ini bentuk yang lumayan umum dipake orang kaya gini

# %%
# axes nya jadi 1 dmensional lagi soalnya 3x1
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# dan biasa orang bisa for loop di dalem axes nya

# %%
fig,axes = plt.subplots(nrows=3,ncols=1)

for ax in axes:
    ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=3,ncols=1)

axes[0].plot(x,y);

# %% [markdown]
# tapi kalo di liat, agak dempet2 jadi keliatan sempit. kita bisa tambahin fig.tight_layout() di akhir biar ga ada yg overlapping

# %%
fig,axes = plt.subplots(nrows=3,ncols=1)

axes[0].plot(x,y)

fig.tight_layout()

# %% [markdown]
# Ini cara manual kalo mau custom jarak spacing nya

# %% [markdown]
# ### Manual spacing on subplots()
#
# Use .subplots_adjust to adjust spacing manually.
#
# Full Details Here: https://matplotlib.org/3.2.2/api/_as_gen/matplotlib.pyplot.subplots_adjust.html
#
# Example from link:
#
# * left = 0.125  # the left side of the subplots of the figure
# * right = 0.9   # the right side of the subplots of the figure
# * bottom = 0.1  # the bottom of the subplots of the figure
# * top = 0.9     # the top of the subplots of the figure
# * wspace = 0.2  # the amount of width reserved for space between subplots,
#               # expressed as a fraction of the average axis width
# * hspace = 0.2  # the amount of height reserved for space between subplots,
#               # expressed as a fraction of the average axis height

# %%
# kita pake plot 4x4 biar lebih gampang liatnya
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(12,8))

# Parameters at the axes level
axes[0][0].plot(a,b)
axes[1][1].plot(x,y)
axes[0][1].plot(y,x)
axes[1][0].plot(b,a);

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(12,8))

# Parameters at the axes level
axes[0][0].plot(a,b)
axes[1][1].plot(x,y)
axes[0][1].plot(y,x)
axes[1][0].plot(b,a)

# pake .subplot_adjust
fig.subplots_adjust(
    wspace=0.5, # ini space width nya
    hspace=0.2, # ini space height
);

# lengkapnya liat di docsnya

# %% [markdown]
# Kalo mau kasih judul figure

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(12,8))

# Parameters at the axes level
axes[0][0].plot(a,b)
axes[1][1].plot(x,y)
axes[0][1].plot(y,x)
axes[1][0].plot(b,a)

# Use left,right,top, bottom to stretch subplots
# Use wspace,hspace to add spacing between subplots
fig.subplots_adjust(left=None,
    bottom=None,
    right=None,
    top=None,
    wspace=0.9,
    hspace=0.1,)

# pake subtitle (super title)
fig.suptitle("Figure Level",fontsize=56)

plt.show()

# %% [markdown]
# ## Exporting plt.subplots()

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(12,8),dpi=200)
# sama kaya figure parameternya


axes[0][0].plot(a,b)
axes[1][1].plot(x,y)
axes[0][1].plot(y,x)
axes[1][0].plot(b,a)

fig.savefig('subplots.png',bbox_inches='tight')
# pake bounding box inches nya tight

plt.show()
