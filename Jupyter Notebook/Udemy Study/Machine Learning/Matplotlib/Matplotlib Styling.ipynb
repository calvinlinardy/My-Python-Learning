# %% [markdown]
# # Matplotlib Legend

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %% [markdown]
# The Data

# %%
x = np.arange(0,10)
y = 2*x

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# skrg kita buat 2 plot di 1 axes
ax.plot(x,x)
ax.plot(x,x**2);

# %% [markdown]
# ini kan kita bingung warna apa itu yang mana, jadi kita bisa bikin legend. pertama bikin label dulu di tiap plot, abis itu tinggal munculin legendnya

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# bikin label di parameter
ax.plot(x,x,label='x vs x')
ax.plot(x,x**2,label='x vs x^2');

# munculin legendnya
ax.legend();

# %% [markdown]
# kita juga bisa tentuin posisi legendnya di parameter legend. kalo mau liat full nya bisa buka docs legendnya, cari bagian parameter loc. kita bisa masukin string buat peletakannya ato juga masukin int atau angkanya

# %% [markdown]
# notes di bawah

# %%
# Lots of options....

ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner

# .. many more options are available

# Most common to choose
ax.legend(loc=0) # let matplotlib decide the optimal location
fig

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x,label='x vs x')
ax.plot(x,x**2,label='x vs x^2');

# contoh kiri bawah
ax.legend(loc='lower left');

# %% [markdown]
# kadang kita mau taro legend nya di luar figure nya, jadi kita harus set manual location legendnya, caranya masukin array kayak axes juga

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x,label='x vs x')
ax.plot(x,x**2,label='x vs x^2');

ax.legend(loc=[1.1,0.5]);

# %% [markdown]
# ato kalo mau taro di kiri

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x,label='x vs x')
ax.plot(x,x**2,label='x vs x^2');

ax.legend(loc=[-0.3,0.5]);

# %% [markdown]
# ## Setting colors, linewidths, linetypes
#
# Matplotlib gives you *a lot* of options for customizing colors, linewidths, and linetypes.
#
# There is the basic MATLAB like syntax (which I would suggest you avoid using unless you already feel really comfortable with MATLAB). Instead let's focus on the keyword parameters.
#
# ### Quick View:

# %% [markdown]
# ### Colors with MatLab like syntax

# %% [markdown]
# With matplotlib, we can define the colors of lines and other graphical elements in a number of ways. First of all, we can use the MATLAB-like syntax where `'b'` means blue, `'g'` means green, etc. The MATLAB API for selecting line styles are also supported: where, for example, 'b.-' means a blue line with dots:

# %%
fig,ax = plt.subplots()
# ini buat hafalin aja
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--'); # green dashed line

# %% [markdown]
# ## Suggested Approach: Use keyword arguments
#
# ### Colors with the color parameter

# %% [markdown]
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using the `color` and `alpha` keyword arguments. Alpha indicates opacity.

# %% [markdown]
# bisa pake nama warnanya, atau kalo mau lebih spesifik pake rgb hex code nya, sama parameter alpah buat tranparency

# %% [markdown]
# sebenernya ada cara lain buat atur warnanya tapi ga perlu lah, ini udah lebih dari cukup

# %%
fig,ax = plt.subplots()

ax.plot(x, x+1, color='blue', alpha=0.5) # setengah transparah
ax.plot(x, x+2, color='#8B008B') # hex
ax.plot(x, x+3, color='#FF8C00'); # hex cari di google

# %% [markdown]
# ## Line and marker styles
# garis nya

# %% [markdown]
# ## Linewidth
#
# To change the line width, we can use the `linewidth` or `lw` keyword argument.

# %%
fig,ax = plt.subplots(figsize=(12,6))

# bisa pake linewidth ato lw, terserah
ax.plot(x, x-1, color='red', linewidth=0.25)
ax.plot(x, x-2, color='red', linewidth=0.5)
ax.plot(x, x-3, color='red', lw=1)
ax.plot(x, x-4, color='red', lw=10);

# %% [markdown]
# ## Linestyles
#
# There are many linestyles to choose from, here is the selection:

# %%
# possible linestype options ‘--‘, ‘–’, ‘-.’, ‘:’, ‘steps’
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x-1, color="green", lw=3, linestyle='-') # solid
ax.plot(x, x-2, color="green", lw=3, ls='-.') # dash and dot
ax.plot(x, x-3, color="green", lw=3, ls=':') # dots
ax.plot(x, x-4, color="green", lw=3, ls='--'); # dashes
